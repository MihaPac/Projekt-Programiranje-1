# %%
# The usual preamble
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# Make the graphs a bit prettier, and bigger
pd.set_option('display.mpl_style', 'default')

# This is necessary to show lots of columns in pandas 0.12. 
# Not necessary in pandas 0.13.
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)

plt.rcParams['figure.figsize'] = (15, 5)

# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

pd.set_option('display.mpl_style', 'default')
plt.rcParams['figure.figsize'] = (15, 3)
plt.rcParams['font.family'] = 'sans-serif'
# Out:
# C:\Users\Miha\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2881: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
bid = pd.read_csv('Data/Strani/izdelki_ebay_bid.csv')
bid = bid.drop_duplicates()
buy = pd.read_csv('Data/Strani/izdelki_ebay_buy.csv')
buy = buy.drop_duplicates()
vse = pd.concat([bid, buy])
# Out:
# 10690

# %%
#izdelki_bid['Bids'].value_counts()
#izdelki_bid['Bids'].plot()

fixed_df = pd.read_csv('Data/Strani/izdelki_ebay_bid.csv', sep=',', encoding='UTF-8', parse_dates=['Cas'], dayfirst=True, index_col='Cas')
fixed_df[:3]
drzave = pd.read_csv('Data/Strani/izdelki_ebay_bid.csv', sep=',', encoding='UTF-8', parse_dates=['Drzava'], index_col='Drzava')
drzave = drzave.drop(['Cena_Buy', 'Buy'], axis=1)
drzave = drzave.drop_duplicates()
#Rezultati prikazani kot tabela sortirana po drzavi
imena = pd.read_csv('Data/Strani/izdelki_ebay_bid.csv', sep=',', encoding='UTF-8', parse_dates=['Ime'], index_col='Ime')
imena = imena.drop(['Cena_Buy', 'Buy'], axis=1)
imena = imena.drop_duplicates()

# %%
fixed_df['Bids'].plot() 
#Tabela odvisnosti stevila ponudb od casa do prodaje izdelka. Najvec ponudb je tik preden se proda izdelek.

# %%
kitajski = bid[bid['Drzava'] == "China"]

# %%
kitajski_popularni = bid[(bid['Drzava'] == "China") & (bid['Bids'] != 0)]

# %%
kitajski_popularni.sort_values('Bids')[-5:]
#Najbolj popularni kitajski izdelki
# Out:
#                                                      Ime  Cena_Bid  Bids Cena_Buy   Buy                  Cas Drzava                 Kategorija
# 15879  For Guitar Maker Mandolin tailpiece Replacemen...      4.33    18     None  None  2017-01-21 02:38:09  China                     String
# 9402   New Universal LED USB Charger Doctor Voltage C...      8.89    20     None  None  2017-01-21 02:10:47  China  Gadgets-Other-Electronics
# 9406                                            RDA Rack      5.00    21     None  None  2017-01-21 02:15:55  China  Gadgets-Other-Electronics
# 7741   ABUNDANCE CRYSTAL MEDICINE BAG Pocket Size Dee...     15.26    22     None  None  2017-01-20 23:36:14  China     Rocks-Fossils-Minerals
# 18899    Flame Warrior High Quality Harness for children     31.77    26     None  None  2017-01-21 00:00:47  China    Outdoor-Toys-Structures

# %%
bid.plot(x='Cena_Bid', y='Bids') 
#Ocitno ni povezave med stevilom ponudnikov in cene, ne da sploh da smiseln graf

# %%
#result = drzave.apply(pd.value_counts).fillna(0); result

# %%
#drzave.plot()

# %%
#drzave.plot(y=('Ime'), kind='bar')

# %%
imena.sort_values("Bids")[-10:]
#15 izdelkov na "Bid" sistem, ki imajo najvec ponudnikov.
# Out:
#                                                     Cena_Bid  Bids                  Cas          Drzava                 Kategorija
# Ime
# Bielenda PROFESSIONAL FORMULA Moisturizing Hydr...      3.08    33  2017-01-20 20:48:36   United States                  Skin-Care
# Sterling Silber  Mondstein  Kreuz  aus Bali            38.10    33  2017-01-21 00:12:33   United States               Fine-Jewelry
# Sterling Silber  Mondstein  Kreuz  aus Bali            38.10    35  2017-01-21 00:12:33   United States               Fine-Jewelry
# harman kardon onyx studio                              69.00    35  2017-01-20 22:50:02   United States  Portable-Audio-Headphones
# Fine Old Chinese Large Carved Wood Lid Top Carv...    183.00    39  2017-01-20 19:57:24   United States             Asian-Antiques
# Sony PlayStation VR Headset                           440.00    40  2017-01-22 20:29:22   United States            Virtual-Reality
# Fine Old Chinese Kangxi Period Blue and White P...    152.50    42  2017-01-20 19:58:25   United States             Asian-Antiques
# Nintendo WII console bundle                            82.54    43  2017-01-21 00:06:21          Canada        Video-Game-Consoles
# AKG Wirless Mic System                                800.00    65  2017-01-20 22:16:52  United Kingdom        Pro-Audio-Equipment
# lot of two old knifes                                  55.00    66  2017-01-20 21:23:14   United States       Knives-Swords-Blades

# %%
imena.sort_values("Cena_Bid")[-10:]
#10 najdrazjih izdelkov na "Bid" sistem, ne glede na drzavo
# Out:
#                                                     Cena_Bid  Bids                  Cas          Drzava                    Kategorija
# Ime
# Tibet buddhism bronze gilt Inlay Turquoise cora...    792.00     0  2017-01-20 20:10:54  United Kingdom                Asian-Antiques
# John Lewis Mikkel Medium Sofa in Zarao Blue Grey      798.53     0  2017-01-20 20:29:44  United Kingdom                     Furniture
# Gemeinhardt ALL Silver Flute USA Elkhart              799.00     0  2017-01-21 01:36:00   United States                 Wind-Woodwind
# AKG Wirless Mic System                                800.00    65  2017-01-20 22:16:52  United Kingdom           Pro-Audio-Equipment
# Vacation rental home with private pool to rent ...    800.00     0  2017-01-22 14:26:48   United States                       Lodging
# saprano saxophone                                     850.00     0  2017-01-21 03:40:39   United States   Vintage-Musical-Instruments
# Antique Sterling Silver Christening Mug  Art De...    875.00     0  2017-01-21 20:03:59   United States  Keepsakes-Baby-Announcements
# Art Deco Bronze Sculpture of Elegant Lady Dancer      899.79    10  2017-01-20 23:32:56           China               Decorative-Arts
# Derek Jeter Game Used Autographed Batting Glove...    899.99    16  2017-01-21 05:28:09   United States         Game-Used-Memorabilia
# Antique Sand Cast Bronze Plaque Crest Pointer H...    950.00     0  2017-01-20 23:25:49   United States               Decorative-Arts

# %%
vse_drzave = bid.drop(["Cena_Bid", 'Ime', 'Cena_Buy', 'Buy', 'Cas', 'Kategorija', 'Bids'], axis=1)
vse_drzave = vse_drzave.drop_duplicates()

# %%
counts = bid.groupby('Drzava').size() 
counts.sort_values().plot.bar()
counts.sort_values()
#Tabela in graf stevila izdelkov na ponudbo v drzavi, Slovenija ima en izdelek! Ker je Ebay Ameriska
#internetna stran tudi ni presenetljivo, da je velika vecina izdelkov iz Amerike.
# Out:
# Drzava
# Algeria                  1
# Kenya                    1
# Venezuela                1
# Malta                    1
# Mauritania               1
# Mexico                   1
# Panama                   1
# Ireland                  1
# Peru                     1
# Portugal                 1
# Puerto Rico              1
# Serbia                   1
# Slovenia                 1
# South Africa             1
# Uganda                   1
# Poland                   1
# Indonesia                1
# Malaysia                 1
# Vietnam                  1
# Austria                  1
# Belgium                  1
# Hungary                  1
# Czech Republic           1
# Slovakia                 2
# Romania                  2
# Turkey                   2
# Taiwan                   2
# Latvia                   2
# Argentina                2
# New Zealand              3
# Denmark                  3
# Norway                   4
# Russian Federation       4
# Ukraine                  5
# Netherlands              6
# Belarus                  6
# Cyprus                   6
# Israel                   6
# Estonia                  7
# Bulgaria                 7
# Greece                   8
# Thailand                11
# Spain                   16
# Japan                   28
# Hong Kong               37
# Italy                   46
# India                   48
# Canada                  59
# France                  73
# Australia               91
# Germany                 99
# China                  299
# United Kingdom         931
# United States         2599
# dtype: int64
